# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalGhimire38/Extra_Python_Stuffs/blob/main/Matplotlib_Revision_from_w3shcools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2082/10/10  08:04 PM,  @Har Har Mahadev
# # Matplotlib Revision from w3shcools

# %% [markdown]
# [Course Link](https://www.w3schools.com/python/matplotlib_pyplot.asp)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Plotting Without Line

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# # Multiple Points
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# The plot() function in Matplotlib is the primary tool for creating 2D line plots and scatter plots, by connecting given x and y data points. It is highly customizable, allowing control over line styles, colors, markers, and other properties.
# Basic Usage
# The most common way to use plot() is through the pyplot interface, typically imported as plt.
# python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # 1. Prepare your data (lists or numpy arrays)
# xpoints = np.array([1, 2, 6, 8])
# ypoints = np.array([3, 8, 1, 10])
#
# # 2. Plot the data
# plt.plot(xpoints, ypoints)
#
# # 3. Add labels and a title (optional but recommended)
# plt.xlabel("X-axis Label")
# plt.ylabel("Y-axis Label")
# plt.title("Simple Line Plot")
#
# # 4. Display the plot
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Default X-Points
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
ypoints = np.array([3,8,1,10,5,7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %%
plt.plot(ypoints, marker = 'X')
plt.show()

# %% [markdown]
# # Format Strings fmt
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
plt.plot(ypoints, '*:r')
plt.show()

plt.plot(ypoints, marker='o', ms=20)

# %%
plt.plot(ypoints, marker='o', ms=20, mec='r', mfc='b') # marker edge color, marker face color

# %% [markdown]
# # Matplotlib Line

# %%
plt.plot(ypoints, linestyle='dotted', marker='*')
plt.show()

# %%
plt.plot(ypoints, linestyle='dashed', marker='*')
plt.show()

# %% [markdown]
# Shorter Syntax
# The line style can be written in a shorter syntax:
#
# linestyle can be written as ls.
#
# dotted can be written as :.
#
# dashed can be written as --.

# %%
plt.plot(ypoints, ls=':', marker='*')
plt.show()

# %% [markdown]
# # Multiple Lines

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1)
plt.plot(y2)

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# # 2082/10/12  08:58 PM
#
# [Course Progress](https://www.w3schools.com/python/matplotlib_line.asp)

# %% [markdown]
# # Matplotlib Labels and Title

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y,color='r',ls=':',marker='X',mec='b')

plt.xlabel("Average Pulse")
plt.ylabel(("Calorie Burnage"))

plt.show()

# %% [markdown]
# # Create a Title for a Plot

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y,color='black',ls=':',marker='X',mec='b')

plt.xlabel("Average Pulse")
plt.ylabel(("Calorie Burnage"))
plt.title("Sports Watch Data")

plt.show()

# %% [markdown]
# # Set Font Properties for Title and Labels

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1 = {
    'family':'serif',
    'color':'blue',
    'size':'20'
}

font2 = {
    'family':'serif',
    'color':'darkred',
    'size':15
}

plt.plot(x,y,color='r',ls=':',marker='X',mec='b')


plt.title("Sports Watch Data", fontdict=font1)
plt.xlabel("Average Pulse", fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)

plt.show()

# %%
# Position the Title
plt.title("Sports Watch Data", loc='left')
plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# ## Specify Which Grid Lines to Display

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y,ls='-',color='b',marker='X')
plt.grid(axis='x')

# %% [markdown]
# # Set Line Properties for the Grid

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y, marker='*')

plt.grid(color='g',linestyle='--',linewidth=0.5)

plt.show()
