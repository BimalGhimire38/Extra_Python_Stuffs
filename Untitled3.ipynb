# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalGhimire38/Extra_Python_Stuffs/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2082/09/17  05:09 PM
#
# ![image.png](data:image/png;base64,...)

# %%
import calender
def glass(text):
  lines = text.splitlines()
