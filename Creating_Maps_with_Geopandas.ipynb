# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalGhimire38/Extra_Python_Stuffs/blob/main/Creating_Maps_with_Geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2082/09/07  11:11 AM

# %%
# !pip install geodatasets

# %%
# Example data
import geodatasets, geopandas

chicago = geopandas.read_file(geodatasets.get_path("geoda.chicago_commpop"))
groceries = geopandas.read_file(geodatasets.get_path("geoda.groceries"))
# Out:
# ...
# Extracting 'chicago_commpop/chicago_commpop.geojson' from '/root/.cache/geodatasets/chicago_commpop.zip' to '/root/.cache/geodatasets/chicago_commpop.zip.unzip'
# ...
# Extracting 'grocery/chicago_sup.shp' from '/root/.cache/geodatasets/grocery.zip' to '/root/.cache/geodatasets/grocery.zip.unzip'
# Extracting 'grocery/chicago_sup.dbf' from '/root/.cache/geodatasets/grocery.zip' to '/root/.cache/geodatasets/grocery.zip.unzip'
# Extracting 'grocery/chicago_sup.shx' from '/root/.cache/geodatasets/grocery.zip' to '/root/.cache/geodatasets/grocery.zip.unzip'
# Extracting 'grocery/chicago_sup.prj' from '/root/.cache/geodatasets/grocery.zip' to '/root/.cache/geodatasets/grocery.zip.unzip'

# %%
chicago.head()
# Out:
#          community  NID  POP2010  POP2000  POPCH   POPPERCH  popplus  popneg  \
# 0          DOUGLAS   35    18238    26470  -8232 -31.099358        0       1
# 1          OAKLAND   36     5918     6110   -192  -3.142390        0       1
# 2      FULLER PARK   37     2876     3420   -544 -15.906433        0       1
# 3  GRAND BOULEVARD   38    21929    28006  -6077 -21.698922        0       1
# 4          KENWOOD   39    17841    18363   -522  -2.842673        0       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...
# 1  MULTIPOLYGON (((-87.59215 41.81693, -87.59231 ...
# 2  MULTIPOLYGON (((-87.6288 41.80189, -87.62879 4...
# 3  MULTIPOLYGON (((-87.60671 41.81681, -87.6067 4...
# 4  MULTIPOLYGON (((-87.59215 41.81693, -87.59215 ...

# %%
chicago.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Choropleth Maps
#
# Choropleth maps are those type of maps wherre the color of each shape is based on the value of an associates variable

# %%
chicago.plot(column='POP2010')
# Out:
# <Axes: >

# %% [markdown]
# # Creating a Legend

# %%
chicago.plot(column='POP2010', legend=True)
# Out:
# <Axes: >

# %%
chicago.plot(
    column="POP2010",
    legend =  True,
    legend_kwds={'label':'population in 2010','orientation':'horizontal'}
)
# Out:
# <Axes: >
